# %%
myPath = ''

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

faro = cv2.imread(myPath+'img/kodim19.png')
faroc = cv2.cvtColor(faro, cv2.COLOR_BGR2RGB) # Matplotlib espera RGB
plt.xticks([]), plt.yticks([])
plt.imshow(faroc)

# %%
K = 16
kernel = np.ones((K,K),np.float32)/(K*K)
dst = cv2.filter2D(faroc,-1,kernel)
plt.subplot(121),plt.imshow(faroc),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
blur = cv2.blur(faroc,(50,5))
plt.subplot(121),plt.imshow(faroc),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blured')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img_noisy = np.copy(faroc)
rows, cols, color = faroc.shape
noise = 100000
for i in range(noise):
        # Pick a random y coordinate
        y_coord = np.random.randint(0, rows - 1)
        # Pick a random x coordinate
        x_coord = np.random.randint(0, cols - 1)
        # Pick a random color
        color_coord = np.random.randint(0,color - 1)
        # Color that pixel to white
        img_noisy[y_coord][x_coord][color_coord] = 255

for i in range(noise):
        # Pick a random y coordinate
        y_coord = np.random.randint(0, rows - 1)
        # Pick a random x coordinate
        x_coord = np.random.randint(0, cols - 1)
        # Pick a random color
        color_coord = np.random.randint(0,color - 1)
        # Color that pixel to black
        img_noisy[y_coord][x_coord][color_coord] = 0


median = cv2.medianBlur(img_noisy,5)

plt.subplot(121),plt.imshow(img_noisy),plt.title('Noisy')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(median),plt.title('Filtered')
plt.xticks([]), plt.yticks([])
plt.show()
