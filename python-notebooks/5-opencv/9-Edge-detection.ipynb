# %% [markdown]
# # Image Gradients
#
# ## Sobel Operators
#
# Es una gausseana + un diferenciador aplicado en alguna dirección.
#
# ## Derivadores Laplacianos
#
# Es simplemente utilizar el operador laplaciano que se compone de las derivadas parciales segundas en ambas direcciones
#
# $$\bigtriangleup src = {{\delta^2 src} \over {\delta x^2}} +{{\delta^2 src} \over {\delta y^2}}$$

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('img/sudoku.jpg',0)

laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

plt.subplot(2,2,1)
plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Canny Edge Detection
# Es un algoritmo clásico de detección de bordes, se resume en los siguientes pasos:
#
# 1- Apply Gaussian filter to smooth the image in order to remove the noise
#
# 2- Find the intensity gradients of the image. Mediante el filtro de Sobel, se calcula la derivada en X y en Y y se obtiene el gradiente:
#
# $$Edge\_Gradient(G) = \sqrt{G_x ^2 + G_y ^2}$$
# $$Angle(\theta) = tan^{-1} ( {{G_y} \over {G_x} } )$$
#
# 3- Apply non-maximum suppression to get rid of spurious response to edge detection
#
# 4- Apply double threshold to determine potential edges
#
# 5- Track edge by hysteresis: Finalize the detection of edges by suppressing all the other edges that are weak and not connected to strong edges.

# %%
edges = cv2.Canny(img,30,100)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
#Lo mismo pero con la imagen del faro
faro = cv2.imread('img/kodim19.png',0)
edges = cv2.Canny(faro,30,100)

plt.subplot(121),plt.imshow(faro,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()
