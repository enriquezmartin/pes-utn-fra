# %% [markdown]
# # Aliasing on Images
# Simplemente vamos a ver como se ve el alias en una imagen

# %%
from google.colab import drive
drive.mount('/content/drive')
myPath = '/content/drive/MyDrive/PES/python-notebooks/2-sampling'
# Out:
# Mounted at /content/drive

# %%
import scipy.signal as sig
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open(myPath+'/img/bricks.jpg')
plt.figure(figsize = (100,100))
print (img.size)
plt.imshow(img, interpolation='nearest')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#img.thumbnail((500, 500), Image.ANTIALIAS)
#img = img.resize((200, 200), img.ANTIALIAS)
print (img.size)
plt.figure(figsize = (5,5))
plt.imshow(img, interpolation='nearest')
# Out:
# (622, 756)

# %%
img.thumbnail((124, 151), Image.ANTIALIAS)
#img = img.resize((200, 200), img.ANTIALIAS)
print (img.size)
plt.figure(figsize = (5,5))
plt.imshow(img, interpolation='nearest')
# Out:
# (124, 151)
# <ipython-input-4-2f151d48285d>:1: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img.thumbnail((124, 151), Image.ANTIALIAS)
